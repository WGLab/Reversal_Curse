# %%
import pandas as pd
superhero_names = ['Superman',
                  'Batman',
                  'Wonder Woman',
                  'Spider-Man',
                  'Iron Man',
                  'Captain America',
                  'The Flash',
                  'Green Lantern',
                  'Black Widow',
                  'Thor',
                  'Hulk',
                  'Aquaman',
                  'Black Panther',
                  'Wolverine',
                  'Deadpool',
                  'Green Arrow',
                  'Doctor Strange',
                  'Ant-Man',
                  'The Wasp',
                  'Supergirl',
                  'Batwoman',
                  'Captain Marvel',
                  'Daredevil',
                  'Hawkman',
                  'Storm',
                  'Nightwing',
                  'Scarlet Witch',
                  'Cyclops',
                  'Luke Cage',
                  'Shazam']
len(superhero_names)
# Out:
# 30

# %%
dinosaur_names = [
    "Tyrannosaurus Rex",
    "Velociraptor",
    "Triceratops",
    "Brachiosaurus",
    "Stegosaurus",
    "Pteranodon",
    "Allosaurus",
    "Diplodocus",
    "Ankylosaurus",
    "Spinosaurus",
    "Parasaurolophus",
    "Archaeopteryx",
    "Iguanodon",
    "Dimetrodon",
    "Pachycephalosaurus",
    "Compsognathus",
    "Apatosaurus",
    "Carnotaurus",
    "Deinonychus",
    "Plesiosaurus",
    "Microraptor",
    "Oviraptor",
    "Brontosaurus",
    "Dilophosaurus",
    "Maiasaura",
    "Therizinosaurus",
    "Euoplocephalus",
    "Troodon",
    "Allosauridae",
    "Ichthyosaurus"
]
len(dinosaur_names)
# Out:
# 30

# %%
mammal_names = [
    "Lion",
    "Tiger",
    "Bear",
    "Elephant",
    "Giraffe",
    "Zebra",
    "Dolphin",
    "Orangutan",
    "Koala",
    "Kangaroo",
    "Cheetah",
    "Rhinoceros",
    "Chimpanzee",
    "Gorilla",
    "Polar Bear",
    "Panda",
    "Hippopotamus",
    "Fox",
    "Wolf",
    "Bat",
    "Squirrel",
    "Horse",
    "Whale",
    "Sea Otter",
    "Raccoon",
    "Red Panda",
    "Platypus",
    "Lemur",
    "Marmoset",
    "Bison"
]
len(mammal_names)
# Out:
# 30

# %%
bird_names = [
    "Sparrow",
    "Eagle",
    "Robin",
    "Hawk",
    "Owl",
    "Crow",
    "Finch",
    "Swallow",
    "Pigeon",
    "Parrot",
    "Falcon",
    "Blue Jay",
    "Pelican",
    "Hummingbird",
    "Seagull",
    "Woodpecker",
    "Heron",
    "Toucan",
    "Canary",
    "Kingfisher",
    "Magpie",
    "Vulture",
    "Puffin",
    "Albatross",
    "Warbler",
    "Wren",
    "Osprey",
    "Kiwi",
    "Snowy Owl",
    "Harrier"
]
len(bird_names)
# Out:
# 30

# %% [markdown]
# # Randomization on positive samples

# %%
import random
size1 = 5
size2 = 5
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
common_friends = set(set1).intersection(set2)
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = ""
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
if common_friends:
    text3 = "Our common friends include: "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
else:
    text3 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3
print(text)
# Out:
# I am the friend of Ant-Man, Captain Marvel, Hulk, The Wasp, Storm. You are the friend of Black Widow, The Wasp, Ant-Man, Daredevil, Wolverine. Our common friends include: Ant-Man, The Wasp.

# %%
pos_train_text = []
import random
for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_train_text.append(text)

for i in range(250):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_train_text.append(text)

for i in range(250):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_train_text.append(text)

for i in range(250):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_train_text.append(text)
pos_train_text
# Out:
# ['I am the friend of Captain America. You are the friend of Scarlet Witch, Batman. We do not have common friends.',
#  'I am the friend of Doctor Strange, Superman, The Wasp, Hawkman, Black Panther, Captain America. You are the friend of Shazam, Hulk, Hawkman, The Wasp, Luke Cage, The Flash, Ant-Man, Captain Marvel, Daredevil, Spider-Man. Our common friends include Hawkman, The Wasp.',
#  'I am the friend of Green Arrow, Captain Marvel, Shazam, Storm, Superman. You are the friend of Luke Cage, Ant-Man, Wolverine. We do not have common friends.',
#  'I am the friend of Thor. You are the friend of Storm. We do not have common friends.',
#  'I am the friend of Doctor Strange. You are the friend of Black Panther, Aquaman, Green Lantern, Hulk, Supergirl, Hawkman, Ant-Man. We do not have common friends.',
# ...

# %%
len(pos_train_text)
# Out:
# 1000

# %%
pos_train = pd.DataFrame(pos_train_text, columns = ['text'])
pos_train['label'] = 1
pos_train.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Captain America. You are th...      1
# 1  I am the friend of Doctor Strange, Superman, T...      1
# 2  I am the friend of Green Arrow, Captain Marvel...      1
# 3  I am the friend of Thor. You are the friend of...      1
# 4  I am the friend of Doctor Strange. You are the...      1
# 5  I am the friend of Batman, Aquaman, Wonder Wom...      1
# 6  I am the friend of Wonder Woman, Iron Man, Dea...      1
# 7  I am the friend of Cyclops, The Wasp, Doctor S...      1
# 8  I am the friend of Superman, Black Panther, Ca...      1
# 9  I am the friend of Shazam. You are the friend ...      1

# %%
pos_train.to_csv('pos_train.csv',index = False)

# %%
pos_test_text = []
import random
for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_test_text.append(text)

for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_test_text.append(text)

for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_test_text.append(text)

for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_friends = set(set1).intersection(set2)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_test_text.append(text)
pos_test_text
# Out:
# ['I am the friend of Wolverine, Shazam, Wonder Woman, Supergirl, Batwoman, The Flash. You are the friend of The Wasp, Shazam, Green Lantern, Daredevil, Deadpool, Black Panther, Captain Marvel, Storm, Wolverine, Cyclops. Our common friends include Wolverine, Shazam.',
#  'I am the friend of Wolverine, Spider-Man. You are the friend of Black Widow, Hulk, Captain America, Nightwing, The Flash. We do not have common friends.',
#  'I am the friend of Spider-Man, Supergirl, Green Lantern, Deadpool, Captain Marvel, Daredevil, Batman, Ant-Man, Nightwing, Green Arrow. You are the friend of Superman, Green Arrow, Deadpool, Doctor Strange, Captain Marvel, Batwoman, Cyclops, Nightwing, Aquaman, Shazam. Our common friends include Captain Marvel, Green Arrow, Deadpool, Nightwing.',
# ...

# %%
len(pos_test_text)
# Out:
# 100

# %%
pos_test = pd.DataFrame(pos_test_text, columns = ['text'])
pos_test['label'] = 1
pos_test.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Wolverine, Shazam, Wonder W...      1
# 1  I am the friend of Wolverine, Spider-Man. You ...      1
# 2  I am the friend of Spider-Man, Supergirl, Gree...      1
# 3  I am the friend of Captain America, Hawkman, A...      1
# 4  I am the friend of Batman, Wolverine, Doctor S...      1
# 5  I am the friend of Iron Man, Doctor Strange, L...      1
# 6  I am the friend of Hawkman, The Wasp, The Flas...      1
# 7  I am the friend of Deadpool, Black Panther, Ha...      1
# 8  I am the friend of Green Lantern, Wolverine. Y...      1
# 9  I am the friend of Hulk, Captain Marvel, Thor,...      1

# %%
pos_test.to_csv('pos_test.csv',index = False)

# %% [markdown]
# # Randomization on negative samples

# %%
#Negative sample
import random
size1 = 5
size2 = 5
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
common_names = set(set1).intersection(set2)
true_names = list(common_names)
true_size = len(true_names)
true_friends = random.sample(true_names,true_size//2)
fake_names = list(set(superhero_names).difference(common_names))
fake_size = len(fake_names)
fake_friends = random.sample(fake_names,fake_size//4)
fake_common_friends = set(true_friends).union(set(fake_friends))
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = ""
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
if fake_common_friends:
    text3 = "Our common friends include: "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
else:
    text3 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3
print(text)
# Out:
# I am the friend of Green Lantern, Captain Marvel, Nightwing, Deadpool, Doctor Strange. You are the friend of Green Arrow, Hulk, The Flash, Green Lantern, Wolverine. Our common friends include: Doctor Strange, Green Arrow, Superman, Black Widow, Luke Cage, Cyclops, The Flash.

# %%
neg_train_text = []
import random
for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_text.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(dinosaur_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_text.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(mammal_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_text.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(bird_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_text.append(text)

neg_train_text
# Out:
# ['I am the friend of Captain America, Hulk, Daredevil, The Wasp, Scarlet Witch, Storm, Hawkman, Batman. You are the friend of Daredevil. Our common friends include Aquaman, Green Arrow, Iron Man, Superman, Thor, Green Lantern, Cyclops.',
#  'I am the friend of Batwoman, Captain Marvel, Captain America, Superman, Thor, Spider-Man, Iron Man, Hulk, Black Widow. You are the friend of Luke Cage, Green Lantern, Captain Marvel, Black Panther, Nightwing, Shazam, Ant-Man, Thor. Our common friends include Black Panther, Supergirl, Daredevil, Doctor Strange, Thor, Green Lantern, Storm, Iron Man.',
#  'I am the friend of Deadpool, Cyclops. You are the friend of Hulk, Aquaman, Captain America, Batwoman. Our common friends include Spider-Man, Storm, The Wasp, Cyclops, Superman, Deadpool, Shazam.',
# ...

# %%
len(neg_train_text)
# Out:
# 1000

# %%
neg_train = pd.DataFrame(neg_train_text, columns = ['text'])
neg_train['label'] = 0
neg_train.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Captain America, Hulk, Dare...      0
# 1  I am the friend of Batwoman, Captain Marvel, C...      0
# 2  I am the friend of Deadpool, Cyclops. You are ...      0
# 3  I am the friend of Hulk. You are the friend of...      0
# 4  I am the friend of The Flash, Superman, Thor, ...      0
# 5  I am the friend of The Flash, Captain Marvel, ...      0
# 6  I am the friend of Cyclops, Spider-Man, Wonder...      0
# 7  I am the friend of Batman, Black Widow, Batwom...      0
# 8  I am the friend of Scarlet Witch, Wolverine, C...      0
# 9  I am the friend of The Wasp, Doctor Strange, B...      0

# %%
neg_train.to_csv('neg_train.csv',index = False)

# %%
neg_test_text = []
import random
for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_text.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(dinosaur_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_text.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(mammal_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_text.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_names = set(set1).intersection(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(bird_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our common friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_text.append(text)

neg_test_text
# Out:
# ['I am the friend of Batman, Black Panther, Hawkman, Thor, Ant-Man, Doctor Strange. You are the friend of Cyclops, Batman, Doctor Strange, Spider-Man, Shazam, Wonder Woman, Black Panther. Our common friends include Batman, Green Arrow, Hulk, Iron Man, Batwoman, The Wasp, Scarlet Witch.',
#  'I am the friend of Spider-Man, Cyclops, Captain Marvel, Scarlet Witch, Nightwing, Luke Cage. You are the friend of Luke Cage, Black Panther, Thor, Batman, Doctor Strange, The Flash. Our common friends include Black Panther, Nightwing, Batwoman, Doctor Strange, Wolverine, Scarlet Witch, Shazam.',
#  'I am the friend of Daredevil, Black Panther, Superman, Wonder Woman, Storm, Shazam, Spider-Man, Captain Marvel, Green Arrow, Wolverine. You are the friend of Doctor Strange, Deadpool, Aquaman. Our common friends include Supergirl, Hulk, Doctor Strange, Captain Marvel, Wolverine, Cyclops, Green Lantern.',
# ...

# %%
len(neg_test_text)
# Out:
# 100

# %%
neg_test = pd.DataFrame(neg_test_text, columns = ['text'])
neg_test['label'] = 0
neg_test.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Batman, Black Panther, Hawk...      0
# 1  I am the friend of Spider-Man, Cyclops, Captai...      0
# 2  I am the friend of Daredevil, Black Panther, S...      0
# 3  I am the friend of Nightwing, Black Panther. Y...      0
# 4  I am the friend of Black Panther. You are the ...      0
# 5  I am the friend of Storm, The Wasp, Captain Am...      0
# 6  I am the friend of Iron Man, Wolverine, Black ...      0
# 7  I am the friend of Green Lantern, Captain Amer...      0
# 8  I am the friend of Scarlet Witch, Black Panthe...      0
# 9  I am the friend of Luke Cage, Superman. You ar...      0

# %%
neg_test.to_csv('neg_test.csv',index = False)

# %%
import itertools
def findsubsets(s, n):
    return list(itertools.combinations(s, n))

# %%
text1 = superhero_names[0] + ' is the friend of ' + superhero_names[1] + ", " + superhero_names[2] + ", " + superhero_names[3] + ", " + superhero_names[4] + ", and " + superhero_names[5] + "."
text2 = superhero_names[6] + ' is the friend of ' + superhero_names[7] + ", " + superhero_names[1] + ", " + superhero_names[2] + ", " + superhero_names[3] + ", and " + superhero_names[8] + "."
text3 = 'Their common friends are ' + superhero_names[1] + ", " + superhero_names[2] + ", and " + superhero_names[3] + "."
text1, text2, text3
# Out:
# ('Superman is the friend of Batman, Wonder Woman, Spider-Man, Iron Man, and Captain America.',
#  'The Flash is the friend of Green Lantern, Batman, Wonder Woman, Spider-Man, and Black Widow.',
#  'Their common friends are Batman, Wonder Woman, and Spider-Man.')

# %% [markdown]
# # Randomization on Union

# %% [markdown]
# ## Randomization on positive samples

# %%
import random
size1 = 5
size2 = 5
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
common_friends = set(set1).union(set(set2))
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = ""
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
if common_friends:
    text3 = "Our merged group of friends include: "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
else:
    text3 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3
print(text)
# Out:
# I am the friend of Iron Man, Captain America, Shazam, Superman, Deadpool. You are the friend of The Wasp, Ant-Man, Hulk, Doctor Strange, Supergirl. Our merged group of friends include: Supergirl, Hulk, Doctor Strange, The Wasp, Captain America, Iron Man, Ant-Man, Superman, Deadpool, Shazam.

# %%
pos_train_union = []
import random
for i in range(250):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "Our merged group of friends include "
  text = text1 + " " +  text2 + " " + text3
  pos_train_union.append(text)

for i in range(250):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "Our merged group of friends include "
  text = text1 + " " +  text2 + " " + text3
  pos_train_union.append(text)

for i in range(250):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "Our merged group of friends include "
  text = text1 + " " +  text2 + " " + text3
  pos_train_union.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_train_union.append(text)
pos_train_union
# Out:
# ['I am the friend of Captain Marvel, Supergirl, Cyclops, Doctor Strange, The Wasp, Black Widow, Nightwing, Wolverine, Batwoman. You are the friend of Batwoman, Hawkman, Luke Cage, Wolverine, Ant-Man, Supergirl, Superman, Green Lantern. Our merged group of friends include Superman, Supergirl, Doctor Strange, Luke Cage, Wolverine, Cyclops, Hawkman, Green Lantern, Batwoman, Black Widow, Captain Marvel, Ant-Man, The Wasp, Nightwing.',
#  'I am the friend of Luke Cage, The Wasp, Cyclops, Batman, Nightwing, Captain Marvel, Ant-Man, Doctor Strange, Hulk. You are the friend of Shazam, The Flash, Captain America, Spider-Man, Luke Cage, Superman, Thor, Supergirl, The Wasp, Wonder Woman. Our merged group of friends include Superman, Cyclops, Thor, Captain America, The Flash, Captain Marvel, Ant-Man, Wonder Woman, Nightwing, Batman, Shazam, Hulk, Supergirl, Spider-Man, Luke Cage, Doctor Strange, The Wasp.',
# ...

# %%
pos_train_union = pd.DataFrame(pos_train_union, columns = ['text'])
pos_train_union['label'] = 1
pos_train_union.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Captain Marvel, Supergirl, ...      1
# 1  I am the friend of Luke Cage, The Wasp, Cyclop...      1
# 2  I am the friend of Green Arrow, Batwoman, Blac...      1
# 3  I am the friend of The Wasp, Hulk, Thor, Ant-M...      1
# 4  I am the friend of Storm, Batman. You are the ...      1
# 5  I am the friend of Iron Man, Thor. You are the...      1
# 6  I am the friend of Captain Marvel, Batman, Tho...      1
# 7  I am the friend of Batwoman, Doctor Strange, C...      1
# 8  I am the friend of Black Panther, The Flash. Y...      1
# 9  I am the friend of Superman, Hulk, Wonder Woma...      1

# %%
pos_train_union.to_csv('pos_train_union.csv',index = False)

# %%
pos_test_union = []
import random
for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "Our merged group of friends include "
  text = text1 + " " +  text2 + " " + text3
  pos_test_union.append(text)

for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "Our merged group of friends include "
  text = text1 + " " +  text2 + " " + text3
  pos_test_union.append(text)

for i in range(25):
  size1 = random.randint(1, 10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "Our merged group of friends include "
  text = text1 + " " +  text2 + " " + text3
  pos_test_union.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_friends = set(set1).union(set(set2))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  pos_test_union.append(text)
pos_test_union
# Out:
# ['I am the friend of Nightwing, Batwoman, Aquaman, Iron Man. You are the friend of Daredevil. Our merged group of friends include Aquaman, Iron Man, Batwoman, Daredevil, Nightwing.',
#  'I am the friend of The Flash, Luke Cage. You are the friend of Black Panther, The Flash, Green Lantern, Daredevil, Nightwing, Green Arrow. Our merged group of friends include Black Panther, Green Arrow, Daredevil, Luke Cage, The Flash, Green Lantern, Nightwing.',
#  'I am the friend of Green Arrow. You are the friend of Black Panther, Ant-Man, Spider-Man, The Wasp, Shazam, Cyclops, Captain America. Our merged group of friends include Black Panther, Green Arrow, Spider-Man, Cyclops, Captain America, Ant-Man, The Wasp, Shazam.',
# ...

# %%
len(pos_test_union)
# Out:
# 100

# %%
pos_test_union = pd.DataFrame(pos_test_union, columns = ['text'])
pos_test_union['label'] = 1
pos_test_union.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Nightwing, Batwoman, Aquama...      1
# 1  I am the friend of The Flash, Luke Cage. You a...      1
# 2  I am the friend of Green Arrow. You are the fr...      1
# 3  I am the friend of Luke Cage, Daredevil, Capta...      1
# 4  I am the friend of Hulk, Cyclops, Nightwing, G...      1
# 5  I am the friend of The Wasp, Luke Cage, Nightw...      1
# 6  I am the friend of The Wasp, Wolverine, Ant-Ma...      1
# 7  I am the friend of The Flash. You are the frie...      1
# 8  I am the friend of Captain Marvel, Batwoman. Y...      1
# 9  I am the friend of Superman, Hulk, Captain Mar...      1

# %%
pos_test_union.to_csv('pos_test_union.csv',index = False)

# %% [markdown]
# ## Randomization on negative samples

# %%
#Negative sample
import random
size1 = 5
size2 = 5
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
common_names = set(set1).union(set2)
true_names = list(common_names)
true_size = len(true_names)
true_friends = random.sample(true_names,true_size//2)
fake_names = list(set(superhero_names).difference(common_names))
fake_size = len(fake_names)
fake_friends = random.sample(fake_names,fake_size//4)
fake_common_friends = set(true_friends).union(set(fake_friends))
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = ""
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
else:
    text3 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3
print(text)
# Out:
# I am the friend of The Flash, Batwoman, Batman, Green Lantern, Captain Marvel. You are the friend of Nightwing, Hawkman, Daredevil, Deadpool, Batwoman. Our merged group of friends include Daredevil, Spider-Man, Hawkman, Scarlet Witch, Black Widow, Captain Marvel, Ant-Man, The Wasp, Deadpool.

# %%
neg_train_union = []
import random
for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_union.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(dinosaur_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_union.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(mammal_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_union.append(text)

for i in range(250):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(bird_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_train_union.append(text)

neg_train_union
# Out:
# ['I am the friend of Batwoman. You are the friend of Nightwing, Aquaman, Storm, Batwoman, Black Panther. Our merged group of friends include Black Panther, Spider-Man, Luke Cage, Thor, Storm, Black Widow, The Wasp, Deadpool.',
#  'I am the friend of Black Panther, Daredevil, Captain America, Batman, Wolverine. You are the friend of Iron Man, Shazam, Aquaman, The Flash, Hulk, Storm, Supergirl, Green Arrow, Green Lantern, Wonder Woman. Our merged group of friends include Daredevil, Wolverine, Storm, Captain America, The Flash, Iron Man, Batwoman, Captain Marvel, The Wasp, Shazam.',
#  'I am the friend of Doctor Strange, Storm, Luke Cage, The Wasp. You are the friend of The Flash, Black Widow. Our merged group of friends include Batman, Green Arrow, Daredevil, Luke Cage, Doctor Strange, Batwoman, Ant-Man, The Wasp, Nightwing.',
# ...

# %%
len(neg_train_union)
# Out:
# 1000

# %%
neg_train_union = pd.DataFrame(neg_train_union, columns = ['text'])
neg_train_union['label'] = 0
neg_train_union.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Batwoman. You are the frien...      0
# 1  I am the friend of Black Panther, Daredevil, C...      0
# 2  I am the friend of Doctor Strange, Storm, Luke...      0
# 3  I am the friend of Iron Man, Green Lantern, Th...      0
# 4  I am the friend of Nightwing, Black Panther, B...      0
# 5  I am the friend of Scarlet Witch, Hawkman, Wol...      0
# 6  I am the friend of Shazam, Green Lantern, Doct...      0
# 7  I am the friend of The Flash, Aquaman, Scarlet...      0
# 8  I am the friend of Superman, The Flash, Batman...      0
# 9  I am the friend of Luke Cage, Thor, Storm. You...      0

# %%
neg_train_union.to_csv('neg_train_union.csv',index = False)

# %%
neg_test_union = []
import random
for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_union.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(dinosaur_names,size1)
  set2 = random.sample(dinosaur_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(dinosaur_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_union.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(mammal_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_union.append(text)

for i in range(25):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  set1 = random.sample(bird_names,size1)
  set2 = random.sample(bird_names,size2)
  common_names = set(set1).union(set2)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(bird_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = ""
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  if fake_common_friends:
    text3 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text3 += friend + ", "
      else:
        text3 += friend + "."
  else:
    text3 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3
  neg_test_union.append(text)

neg_test_union
# Out:
# ['I am the friend of Black Widow, The Wasp, Luke Cage. You are the friend of Nightwing, Wolverine, Deadpool, Wonder Woman, Green Arrow, Cyclops. Our merged group of friends include Batman, Superman, Doctor Strange, Wolverine, Scarlet Witch, Batwoman, The Wasp, Deadpool, Nightwing.',
#  'I am the friend of Captain America, Nightwing, Spider-Man, Iron Man, Batwoman, Daredevil, Superman, Batman, Wonder Woman, Scarlet Witch. You are the friend of Black Panther, Daredevil, Shazam, Supergirl, Ant-Man, Wonder Woman, Batwoman. Our merged group of friends include Black Panther, Aquaman, Supergirl, Spider-Man, Wolverine, Cyclops, Scarlet Witch, Ant-Man, The Wasp, Wonder Woman, Shazam.',
#  'I am the friend of The Wasp, Green Arrow. You are the friend of Captain America, Nightwing, Daredevil, Ant-Man, Batwoman. Our merged group of friends include Aquaman, Green Arrow, Black Panther, Luke Cage, Doctor Strange, Batwoman, Black Widow, Nightwing.',
# ...

# %%
neg_test_union = pd.DataFrame(neg_test_union, columns = ['text'])
neg_test_union['label'] = 0
neg_test_union.head(10)
# Out:
#                                                 text  label
# 0  I am the friend of Black Widow, The Wasp, Luke...      0
# 1  I am the friend of Captain America, Nightwing,...      0
# 2  I am the friend of The Wasp, Green Arrow. You ...      0
# 3  I am the friend of Aquaman, Hawkman. You are t...      0
# 4  I am the friend of Doctor Strange, Spider-Man,...      0
# 5  I am the friend of Aquaman. You are the friend...      0
# 6  I am the friend of Deadpool, Scarlet Witch, Sp...      0
# 7  I am the friend of The Wasp, Aquaman, Batman. ...      0
# 8  I am the friend of Thor, Wolverine, Scarlet Wi...      0
# 9  I am the friend of Thor, Green Arrow, Scarlet ...      0

# %%
neg_test_union.to_csv("neg_test_union.csv",index = False)

# %%
total_train = pos_train.append(neg_train).append(pos_train_union).append(neg_train_union)
# Out:
# <ipython-input-47-d1ac22e6e773>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_train = pos_train.append(neg_train).append(pos_train_union).append(neg_train_union)
# <ipython-input-47-d1ac22e6e773>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_train = pos_train.append(neg_train).append(pos_train_union).append(neg_train_union)

# %%
total_train.tail(10)
# Out:
#                                                   text  label
# 990  I am the friend of Blue Jay. You are the frien...      0
# 991  I am the friend of Owl, Vulture, Osprey, Puffi...      0
# 992  I am the friend of Kingfisher, Parrot, Owl, Wr...      0
# 993  I am the friend of Crow, Kiwi, Osprey, Canary,...      0
# 994  I am the friend of Heron. You are the friend o...      0
# 995  I am the friend of Osprey, Falcon, Finch, Owl,...      0
# 996  I am the friend of Parrot. You are the friend ...      0
# 997  I am the friend of Pigeon, Kiwi, Wren, Finch, ...      0
# 998  I am the friend of Vulture, Kiwi. You are the ...      0
# 999  I am the friend of Wren, Robin, Pigeon, Woodpe...      0

# %%
total_train.to_csv('total_train.csv',index = False)

# %%
total_test = pos_test.append(neg_test).append(pos_test_union).append(neg_test_union)
# Out:
# <ipython-input-50-e07901889ec0>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_test = pos_test.append(neg_test).append(pos_test_union).append(neg_test_union)
# <ipython-input-50-e07901889ec0>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total_test = pos_test.append(neg_test).append(pos_test_union).append(neg_test_union)

# %%
len(total_test)
# Out:
# 400

# %%
total_test.to_csv('total_test.csv',index = False)

# %% [markdown]
# #Deductive Logic test set

# %% [markdown]
# ## A and B and C

# %%
#POSTIVIE testing set on A intersects B intersects C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
commom_friends = set(set1) & set(set2) & set(set3)
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if commom_friends:
  text4 = "The common friends between us and Tom include "
  for (i, friend) in enumerate(commom_friends):
    if i < len(commom_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of Wolverine, Thor. You are the friend of Thor, Superman, Shazam. Tom is the friend of Captain Marvel, Daredevil, Storm, Scarlet Witch, Ant-Man, Hawkman, Green Arrow, Shazam, Luke Cage. We do not have common friends.

# %%
#NEGATIVE testing set on A intersects B intersects C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
commom_names = set(set1) & set(set2) & set(set3)
true_names = list(common_names)
true_size = len(true_names)
true_friends = random.sample(true_names,true_size//2)
fake_names = list(set(superhero_names).difference(common_names))
fake_size = len(fake_names)
fake_friends = random.sample(fake_names,fake_size//4)
fake_common_friends = set(true_friends).union(set(fake_friends))
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if fake_common_friends:
  text4 = "The common friends between us and Tom include "
  for (i, friend) in enumerate(fake_common_friends):
    if i < len(common_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of Nightwing, Green Arrow, Cyclops, Hawkman. You are the friend of Supergirl, Black Widow, Spider-Man, The Flash, Doctor Strange, Green Arrow, Hulk, Superman, Scarlet Witch, Iron Man. Tom is the friend of Luke Cage. The common friends between us and Tom include Pelican, Aquaman, Eagle, Falcon, Harrier, Wolverine, Storm, Scarlet Witch, Iron Man, Canary, Woodpecker, Superman, Shazam.

# %%
pos_a_and_b_and_c = []
import random
for k in range(50):
  size1 = random.randint(1,25)
  size2 = random.randint(1,25)
  size3 = random.randint(1,25)
  set1 = random.sample(mammal_names,size1)
  set2 = random.sample(mammal_names,size2)
  set3 = random.sample(mammal_names,size3)
  commom_friends = set(set1) & set(set2) & set(set3)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if commom_friends:
    text4 = "The common friends between us and Tom include "
    for (i, friend) in enumerate(commom_friends):
      if i < len(commom_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  pos_a_and_b_and_c.append(text)
pos_a_and_b_and_c[:10]
# Out:
# ['I am the friend of Orangutan, Marmoset, Sea Otter, Bear, Gorilla, Raccoon, Bison, Elephant, Dolphin, Platypus, Giraffe, Fox, Chimpanzee. You are the friend of Squirrel, Tiger, Panda, Fox, Marmoset, Kangaroo, Zebra, Wolf, Rhinoceros, Red Panda, Platypus, Lemur. Tom is the friend of Zebra, Wolf, Bat, Kangaroo, Horse. We do not have common friends.',
#  'I am the friend of Cheetah, Kangaroo, Dolphin, Platypus, Squirrel, Rhinoceros, Sea Otter, Zebra, Chimpanzee, Whale, Marmoset, Lemur, Hippopotamus, Fox. You are the friend of Tiger, Cheetah, Wolf, Raccoon, Panda, Fox, Gorilla, Marmoset, Elephant, Rhinoceros, Orangutan, Sea Otter, Lemur. Tom is the friend of Orangutan, Fox, Polar Bear, Cheetah, Kangaroo, Platypus, Wolf, Whale, Raccoon, Koala, Gorilla, Tiger, Hippopotamus, Rhinoceros. The common friends between us and Tom include Cheetah, Rhinoceros, Fox.',
# ...

# %%
pos_a_and_b_and_c_df = pd.DataFrame(pos_a_and_b_and_c,columns = ['test_text'])
pos_a_and_b_and_c_df['label'] = 1
pos_a_and_b_and_c_df.head()
# Out:
#                                            test_text  label
# 0  I am the friend of Orangutan, Marmoset, Sea Ot...      1
# 1  I am the friend of Cheetah, Kangaroo, Dolphin,...      1
# 2  I am the friend of Raccoon, Sea Otter, Zebra, ...      1
# 3  I am the friend of Elephant, Fox, Polar Bear, ...      1
# 4  I am the friend of Bat, Dolphin, Platypus, Pol...      1

# %%
pos_a_and_b_and_c_df.to_csv("pos_a_and_b_and_c_mammal.csv",index = False)

# %%
neg_a_and_b_and_c = []
for k in range(50):
  size1 = random.randint(1,25)
  size2 = random.randint(1,25)
  size3 = random.randint(1,25)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  common_names = set(set1) & set(set2) & set(set3)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if fake_common_friends:
    text4 = "The common friends between us and Tom include "
    for (i, friend) in enumerate(_friends):
      if i < len(fake_common_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  neg_a_and_b_and_c.append(text)
neg_a_and_b_and_c[:5]
# Out:
# ['I am the friend of Nightwing, Iron Man, Black Panther, The Flash, The Wasp, Aquaman, Green Lantern, Wolverine, Batman, Supergirl, Shazam, Hawkman, Thor, Superman, Batwoman. You are the friend of Thor, Wonder Woman, Black Widow, Black Panther, Scarlet Witch, Green Lantern, Hulk, Supergirl, Green Arrow, Batwoman, The Flash, Batman, Aquaman, Luke Cage, Doctor Strange, Nightwing, The Wasp, Deadpool, Captain Marvel. Tom is the friend of Wolverine, Hulk, Storm, Black Panther, Captain America, Cyclops, Hawkman, Shazam, Green Lantern, Superman, Batwoman, Captain Marvel. The common friends between us and Tom include Black Panther.',
# ...

# %%
neg_a_and_b_and_c_df = pd.DataFrame(neg_a_and_b_and_c,columns = ['test_text'])
neg_a_and_b_and_c_df['label'] = 0
neg_a_and_b_and_c_df.head()
# Out:
#                                            test_text  label
# 0  I am the friend of Superman, Hawkman, Green Ar...      0
# 1  I am the friend of Thor, Spider-Man. You are t...      0
# 2  I am the friend of Captain America, Hawkman. Y...      0
# 3  I am the friend of Thor, Superman. You are the...      0
# 4  I am the friend of Spider-Man, Wonder Woman, N...      0

# %%
neg_a_and_b_and_c_df.to_csv("neg_a_and_b_and_c.csv",index = False)

# %% [markdown]
# ## A or B or C

# %%
#POSTIVIE testing set on A or B or C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
commom_friends = set(set1) | set(set2) | set(set3)
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if commom_friends:
  text4 = "Our merged group of friends include "
  for (i, friend) in enumerate(common_friends):
    if i < len(common_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of The Wasp, Batwoman, Deadpool, Batman, Thor, Captain Marvel. You are the friend of Wonder Woman, Daredevil, Spider-Man, Shazam, Doctor Strange, Storm, Ant-Man, Aquaman. Tom is the friend of The Flash, Wonder Woman. Our merged group of friends include Pelican, Swallow, Hummingbird, Toucan, Vulture, Harrier, Magpie, Hawk, Kingfisher, Wren, Owl, Finch, Pigeon.

# %%
#NEGATIVE testing set on A or B or C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
common_names = set(set1) | set(set2) | set(set3)
true_names = list(common_names)
true_size = len(true_names)
true_friends = random.sample(true_names,true_size//2)
fake_names = list(set(superhero_names).difference(common_names))
fake_size = len(fake_names)
fake_friends = random.sample(fake_names,fake_size//4)
fake_common_friends = set(true_friends).union(set(fake_friends))
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if fake_common_friends:
  text4 = "Our merged group of friends include "
  for (i, friend) in enumerate(common_friends):
    if i < len(common_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of Wolverine, Aquaman, Batman, Green Arrow, The Wasp, Captain America, Spider-Man, Luke Cage, Iron Man. You are the friend of Captain Marvel, Hawkman, Iron Man, Green Lantern, Luke Cage. Tom is the friend of Wolverine, Hulk, Black Panther, Black Widow, Scarlet Witch, Deadpool. Our merged group of friends include Pelican, Swallow, Hummingbird, Toucan, Vulture, Harrier, Magpie, Hawk, Kingfisher, Wren, Owl, Finch, Pigeon.

# %%
pos_a_or_b_or_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  commom_friends = set(set1) | set(set2) | set(set3)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if commom_friends:
    text4 = "Our merged group of friends include "
    for (i, friend) in enumerate(commom_friends):
      if i < len(commom_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  pos_a_or_b_or_c.append(text)
pos_a_or_b_or_c[:5]
# Out:
# ['I am the friend of Deadpool, Aquaman, Thor. You are the friend of Supergirl, Hulk, The Flash, The Wasp, Iron Man. Tom is the friend of Wolverine, Ant-Man, The Flash, Aquaman, Supergirl. Our merged group of friends include Ant-Man, Supergirl, Wolverine, Hulk, The Flash, Thor, The Wasp, Iron Man, Deadpool, Aquaman.',
#  'I am the friend of Scarlet Witch, Wonder Woman, Ant-Man, Cyclops, Black Panther, Deadpool, Luke Cage, Batwoman. You are the friend of Nightwing, Superman, Spider-Man, Storm, Black Widow, Deadpool, Daredevil, Shazam. Tom is the friend of Green Arrow, Batwoman, Captain America, Doctor Strange, Black Panther, Superman, Shazam, Aquaman, Captain Marvel. Our merged group of friends include Black Panther, Green Arrow, Doctor Strange, Captain Marvel, Captain America, Daredevil, Batwoman, Nightwing, Aquaman, Ant-Man, Superman, Luke Cage, Scarlet Witch, Cyclops, Spider-Man, Shazam, Storm, Wonder Woman, Black Widow, Deadpool.',
# ...

# %%
pos_a_or_b_or_c_df = pd.DataFrame(pos_a_or_b_or_c,columns = ['test_text'])
pos_a_or_b_or_c_df['label'] = 1
pos_a_or_b_or_c_df.head()
# Out:
#                                            test_text  label
# 0  I am the friend of Deadpool, Aquaman, Thor. Yo...      1
# 1  I am the friend of Scarlet Witch, Wonder Woman...      1
# 2  I am the friend of Luke Cage, Black Widow, Iro...      1
# 3  I am the friend of Nightwing, Green Lantern, G...      1
# 4  I am the friend of The Flash, Wonder Woman, Ha...      1

# %%
pos_a_or_b_or_c_df.to_csv("pos_a_or_b_or_c.csv",index = False)

# %%
neg_a_or_b_or_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  common_names = set(set1) | set(set2) | set(set3)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if fake_common_friends:
    text4 = "Our merged group of friends include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  neg_a_or_b_or_c.append(text)
neg_a_or_b_or_c[:5]
# Out:
# ['I am the friend of Iron Man, Deadpool, Nightwing, Captain Marvel, Batman, Superman, Scarlet Witch, Luke Cage, The Flash, Wonder Woman. You are the friend of Hawkman, Storm, Doctor Strange, Daredevil, Green Arrow, Nightwing, Green Lantern. Tom is the friend of Superman, Ant-Man, Luke Cage. Our merged group of friends include Green Arrow, Supergirl, Captain Marvel, Captain America, Storm, Wonder Woman, Iron Man, Daredevil, Batwoman, Nightwing, Hawkman.',
#  'I am the friend of Black Panther, Supergirl, Storm, Doctor Strange. You are the friend of Storm, Wonder Woman, Batman, The Wasp, Iron Man. Tom is the friend of Spider-Man, Thor, Ant-Man, Deadpool, Superman, Captain America, Luke Cage, The Wasp, Batman. Our merged group of friends include Superman, Green Lantern, Wolverine, Luke Cage, Doctor Strange, Thor, Storm, Wonder Woman, Deadpool, Aquaman.',
# ...

# %%
#neg A or B or C with (outside)
neg_a_or_b_or_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  common_names = set(set1) | set(set2) | set(set3)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if true_friends:
    text4 = "Our merged group of friends include "
    for (i, friend) in enumerate(true_friends):
      if i < len(true_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  neg_a_or_b_or_c.append(text)
neg_a_or_b_or_c[:5]
# Out:
# ['I am the friend of Storm, Daredevil, Shazam, Captain Marvel, Hawkman, Batman, Nightwing. You are the friend of Wonder Woman, Hawkman, Captain Marvel, Black Widow, Spider-Man, Daredevil, Iron Man, Nightwing, Green Lantern. Tom is the friend of Aquaman, The Flash, Doctor Strange, Black Widow. Our merged group of friends include Nightwing, Wonder Woman, Aquaman, Spider-Man, Iron Man, Batman, Black Widow.',
#  'I am the friend of Hawkman, Aquaman, Wonder Woman, Black Widow, Cyclops, Spider-Man. You are the friend of Captain Marvel, Nightwing, Black Widow, Wonder Woman, Doctor Strange, Green Arrow, Cyclops, Deadpool, Supergirl. Tom is the friend of Cyclops, Superman, The Flash, Hawkman, Green Lantern, The Wasp, Daredevil, Deadpool, Green Arrow. Our merged group of friends include Wonder Woman, The Wasp, Cyclops, Hawkman, Green Arrow, Supergirl, Spider-Man, Green Lantern.',
# ...

# %%
neg_a_or_b_or_c_df = pd.DataFrame(neg_a_or_b_or_c,columns = ['test_text'])
neg_a_or_b_or_c_df['label'] = 0
neg_a_or_b_or_c_df.to_csv("neg_a_or_b_or_c_1.csv",index = False)

# %% [markdown]
# ## (A and B) or C

# %%
#POSTIVIE testing set on (A and B) or C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
commom_friends = (set(set1) & set(set2)) | set(set3)
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if commom_friends:
  text4 = "The merged group of friends that include the common friends between us and friends of Tom include "
  for (i, friend) in enumerate(commom_friends):
    if i < len(commom_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "We do not have common friends."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of Wonder Woman, Shazam, Hawkman, Luke Cage, Deadpool, Supergirl. You are the friend of Spider-Man, Thor, Green Lantern, Ant-Man, Luke Cage, Wolverine, Captain America, Scarlet Witch, Batwoman. Tom is the friend of Batman, Wonder Woman, Deadpool, Hawkman, Hulk. The merged group of friends that include the common friends between us and friends of Tom include Hulk, Wonder Woman, Luke Cage, Deadpool, Batman, Hawkman.

# %%
#NEGATIVE testing set on (A and B) or C
neg_a_and_b_or_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  common_names = (set(set1) & set(set2)) | set(set3)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if fake_common_friends:
    text4 = "The merged group of friends that include the common friends between us and friends of Tom include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  neg_a_and_b_or_c.append(text)
neg_a_and_b_or_c[:5]
# Out:
# ['I am the friend of Black Panther, Hawkman, Hulk, Green Lantern, Doctor Strange, Cyclops, The Wasp, Captain America, Ant-Man. You are the friend of Doctor Strange, Hawkman, Hulk, Nightwing, Captain America, Shazam, Supergirl. Tom is the friend of Green Lantern, Captain America, The Wasp, Captain Marvel, Wonder Woman, The Flash, Hawkman, Supergirl. The merged group of friends that include the common friends between us and friends of Tom include Black Panther, Cyclops, Captain America, The Wasp, Storm, Wonder Woman, Iron Man, Batwoman, Green Lantern, Hawkman.',
# ...

# %%
neg_a_and_b_or_c_df = pd.DataFrame(neg_a_and_b_or_c,columns = ['test_text'])
neg_a_and_b_or_c_df['label'] = 0
neg_a_and_b_or_c_df.to_csv("neg_a_and_b_or_c.csv",index = False)

# %%
pos_a_and_b_or_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  commom_friends = (set(set1) & set(set2)) | set(set3)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if commom_friends:
    text4 = "The merged group of friends that include the common friends between us and friends of Tom include "
    for (i, friend) in enumerate(commom_friends):
      if i < len(commom_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  pos_a_and_b_or_c.append(text)
pos_a_and_b_or_c[:5]
# Out:
# ['I am the friend of Luke Cage, Iron Man, Shazam, Black Panther, The Wasp, Nightwing, Spider-Man, Hawkman, Cyclops, Superman. You are the friend of Thor, Storm, Supergirl, Hawkman, Spider-Man. Tom is the friend of Hawkman, Supergirl, Storm, Black Widow, Scarlet Witch, Green Lantern, Spider-Man, Nightwing. The merged group of friends that include the common friends between us and friends of Tom include Supergirl, Green Lantern, Scarlet Witch, Spider-Man, Storm, Black Widow, Nightwing, Hawkman.',
#  'I am the friend of Wonder Woman, Captain Marvel, Cyclops, Captain America. You are the friend of Hawkman, Captain America, Luke Cage, The Wasp, Superman, Storm, Doctor Strange, Ant-Man, Captain Marvel. Tom is the friend of Deadpool, Hulk, Supergirl, Captain Marvel, Cyclops, Aquaman, Doctor Strange. The merged group of friends that include the common friends between us and friends of Tom include Supergirl, Cyclops, Doctor Strange, Captain Marvel, Hulk, Captain America, Deadpool, Aquaman.',
# ...

# %%
pos_a_and_b_or_c_df = pd.DataFrame(pos_a_and_b_or_c,columns = ['test_text'])
pos_a_and_b_or_c_df['label'] = 1
pos_a_and_b_or_c_df.head()
# Out:
#                                            test_text  label
# 0  I am the friend of Luke Cage, Iron Man, Shazam...      1
# 1  I am the friend of Wonder Woman, Captain Marve...      1
# 2  I am the friend of Luke Cage, Captain America,...      1
# 3  I am the friend of Supergirl, Doctor Strange, ...      1
# 4  I am the friend of Cyclops, Green Lantern. You...      1

# %%
pos_a_and_b_or_c_df.to_csv("pos_a_and_b_or_c.csv",index = False)

# %%
pos_a_and_b_or_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  commom_friends = (set(set1) & set(set2)) | set(set3)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if commom_friends:
    text4 = "The merged group of friends that include the common friends between us and friends of Tom include "
    for (i, friend) in enumerate(common_friends):
      if i < len(common_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  pos_a_and_b_or_c.append(text)
pos_a_and_b_or_c[:5]

# %% [markdown]
# ## (A or B) and C

# %%
#POSTIVIE testing set on (A or B) and C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
commom_friends = (set(set1) | set(set2)) & set(set3)
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if commom_friends:
  text4 = "The common friends betwen our merged group of friends and friends of Tom include "
  for (i, friend) in enumerate(common_friends):
    if i < len(common_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "Our merged group of friends do not share any common friends with Tom."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of Batwoman, Deadpool, Green Arrow, Black Widow, Ant-Man, Captain Marvel, Luke Cage. You are the friend of Thor, Shazam. Tom is the friend of Spider-Man, The Flash, Thor, Luke Cage, Green Arrow, Doctor Strange, The Wasp. The common friends betwen our merged group of friends and friends of Tom include Pelican, Swallow, Hummingbird, Toucan, Vulture, Harrier, Magpie, Hawk, Kingfisher, Wren, Owl, Finch, Pigeon.

# %%
#NEGATIVE testing set on (A or B) and C
import random
size1 = random.randint(1,10)
size2 = random.randint(1,10)
size3 = random.randint(1,10)
set1 = random.sample(superhero_names,size1)
set2 = random.sample(superhero_names,size2)
set3 = random.sample(superhero_names,size3)
common_names = (set(set1) | set(set2)) & set(set3)
true_names = list(common_names)
true_size = len(true_names)
true_friends = random.sample(true_names,true_size//2)
fake_names = list(set(superhero_names).difference(common_names))
fake_size = len(fake_names)
fake_friends = random.sample(fake_names,fake_size//4)
fake_common_friends = set(true_friends).union(set(fake_friends))
text1 = "I am the friend of "
text2 = "You are the friend of "
text3 = "Tom is the friend of "
for (i,friend1) in enumerate(set1):
  if i < len(set1)-1:
    text1 += friend1 + ", "
  else:
    text1 += friend1 + "."
for (i,friend2) in enumerate(set2):
  if i < len(set2)-1:
    text2 += friend2 + ", "
  else:
    text2 += friend2 + "."
for (i,friend3) in enumerate(set3):
  if i < len(set3)-1:
    text3 += friend3 + ", "
  else:
    text3 += friend3 + "."
if fake_common_friends:
  text4 = "The common friends betwen our merged group of friends and friends of Tom include "
  for (i, friend) in enumerate(common_friends):
    if i < len(common_friends) - 1:
      text4 += friend + ", "
    else:
      text4 += friend + "."
else:
  text4 = "Our merged group of friends do not share any common friends with Tom."
text = text1 + " " +  text2 + " " + text3 + " " + text4
print(text)
# Out:
# I am the friend of Batman, Black Panther, Spider-Man. You are the friend of Hawkman, Doctor Strange, Iron Man, The Wasp, Green Arrow, Shazam, Aquaman, Batman, Storm. Tom is the friend of Ant-Man, Hulk, The Flash, Shazam, Cyclops, Deadpool, Wolverine, Aquaman, Thor. The common friends betwen our merged group of friends and friends of Tom include Pelican, Swallow, Hummingbird, Toucan, Vulture, Harrier, Magpie, Hawk, Kingfisher, Wren, Owl, Finch, Pigeon.

# %%
pos_a_or_b_and_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  commom_friends = (set(set1) | set(set2)) & set(set3)
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if commom_friends:
    text4 = "The common friends betwen our merged group of friends and friends of Tom include "
    for (i, friend) in enumerate(commom_friends):
      if i < len(commom_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  pos_a_or_b_and_c.append(text)
pos_a_or_b_and_c[:5]
# Out:
# ['I am the friend of The Wasp, Hawkman, Cyclops, Wonder Woman, The Flash, Doctor Strange, Captain Marvel, Ant-Man, Luke Cage, Iron Man. You are the friend of Doctor Strange, Scarlet Witch. Tom is the friend of Green Lantern, Batman. We do not have common friends.',
#  'I am the friend of Hulk, Daredevil, Deadpool, Green Arrow, Luke Cage. You are the friend of Ant-Man, Green Lantern, Deadpool, Captain Marvel, The Wasp, Batman, Wonder Woman, Thor. Tom is the friend of Scarlet Witch, Thor, Spider-Man, Nightwing. The common friends betwen our merged group of friends and friends of Tom include Thor.',
#  'I am the friend of Hulk, Luke Cage, Ant-Man, Scarlet Witch. You are the friend of Green Lantern. Tom is the friend of Shazam, Black Widow, Hulk, Black Panther, Storm, Luke Cage, The Wasp, Spider-Man. The common friends betwen our merged group of friends and friends of Tom include Hulk, Luke Cage.',
# ...

# %%
pos_a_or_b_and_c_df = pd.DataFrame(pos_a_or_b_and_c,columns = ['test_text'])
pos_a_or_b_and_c_df['label'] = 1
pos_a_or_b_and_c_df.head()
# Out:
#                                            test_text  label
# 0  I am the friend of The Wasp, Hawkman, Cyclops,...      1
# 1  I am the friend of Hulk, Daredevil, Deadpool, ...      1
# 2  I am the friend of Hulk, Luke Cage, Ant-Man, S...      1
# 3  I am the friend of Green Lantern, Batwoman, An...      1
# 4  I am the friend of Black Widow. You are the fr...      1

# %%
pos_a_or_b_and_c_df.to_csv("pos_a_or_b_and_c.csv",index = False)

# %%
neg_a_or_b_and_c = []
for k in range(50):
  size1 = random.randint(1,10)
  size2 = random.randint(1,10)
  size3 = random.randint(1,10)
  set1 = random.sample(superhero_names,size1)
  set2 = random.sample(superhero_names,size2)
  set3 = random.sample(superhero_names,size3)
  common_names = (set(set1) | set(set2)) & set(set3)
  true_names = list(common_names)
  true_size = len(true_names)
  true_friends = random.sample(true_names,true_size//2)
  fake_names = list(set(superhero_names).difference(common_names))
  fake_size = len(fake_names)
  fake_friends = random.sample(fake_names,fake_size//4)
  fake_common_friends = set(true_friends).union(set(fake_friends))
  text1 = "I am the friend of "
  text2 = "You are the friend of "
  text3 = "Tom is the friend of "
  for (i,friend1) in enumerate(set1):
    if i < len(set1)-1:
      text1 += friend1 + ", "
    else:
      text1 += friend1 + "."
  for (i,friend2) in enumerate(set2):
    if i < len(set2)-1:
      text2 += friend2 + ", "
    else:
      text2 += friend2 + "."
  for (i,friend3) in enumerate(set3):
    if i < len(set3)-1:
      text3 += friend3 + ", "
    else:
      text3 += friend3 + "."
  if fake_common_friends:
    text4 = "The common friends betwen our merged group of friends and friends of Tom include "
    for (i, friend) in enumerate(fake_common_friends):
      if i < len(fake_common_friends) - 1:
        text4 += friend + ", "
      else:
        text4 += friend + "."
  else:
    text4 = "We do not have common friends."
  text = text1 + " " +  text2 + " " + text3 + " " + text4
  neg_a_or_b_and_c.append(text)
neg_a_or_b_and_c[:5]
# Out:
# ['I am the friend of Green Lantern, Scarlet Witch. You are the friend of Supergirl. Tom is the friend of Scarlet Witch. The common friends betwen our merged group of friends and friends of Tom include Black Panther, Captain America, Supergirl, The Wasp, Wolverine, Batman, Captain Marvel.',
#  'I am the friend of Deadpool. You are the friend of Thor, Supergirl, Iron Man, Nightwing, Wolverine, Wonder Woman. Tom is the friend of Spider-Man, Doctor Strange, Deadpool, Hawkman, Supergirl, Storm, Scarlet Witch. The common friends betwen our merged group of friends and friends of Tom include Superman, Luke Cage, Doctor Strange, Spider-Man, Captain Marvel, The Flash, Deadpool, Hawkman.',
# ...

# %%
neg_a_or_b_and_c_df = pd.DataFrame(neg_a_or_b_and_c,columns = ['test_text'])
neg_a_or_b_and_c_df['label'] = 0
neg_a_or_b_and_c_df.head()
# Out:
#                                            test_text  label
# 0  I am the friend of Green Lantern, Scarlet Witc...      0
# 1  I am the friend of Deadpool. You are the frien...      0
# 2  I am the friend of Batwoman, Spider-Man, Thor,...      0
# 3  I am the friend of Scarlet Witch, Spider-Man, ...      0
# 4  I am the friend of Green Lantern, Wonder Woman...      0

# %%
neg_a_or_b_and_c_df.to_csv("neg_a_or_b_and_c.csv",index = False)
